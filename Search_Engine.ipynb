# %%
pip install PyMuPDF pdfminer.six typesense transformers
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (1.24.9)
# Collecting pdfminer.six
#   Using cached pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Collecting typesense
#   Using cached typesense-0.21.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: transformers in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (4.44.1)
# Requirement already satisfied: PyMuPDFb==1.24.9 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from PyMuPDF) (1.24.9)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from pdfminer.six) (3.3.2)
# Collecting cryptography>=36.0.0 (from pdfminer.six)
#   Using cached cryptography-43.0.0-cp39-abi3-win_amd64.whl.metadata (5.4 kB)
# Requirement already satisfied: requests in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from typesense) (2.32.3)
# Requirement already satisfied: filelock in c:\users\trabe\appdata\roaming\python\python39\site-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\trabe\appdata\roaming\python\python39\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: cffi>=1.12 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\trabe\appdata\roaming\python\python39\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from requests->typesense) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from requests->typesense) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from requests->typesense) (2024.7.4)
# Requirement already satisfied: pycparser in c:\users\trabe\anaconda3\envs\cleanenv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Using cached pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
# Using cached typesense-0.21.0-py3-none-any.whl (21 kB)
# Using cached cryptography-43.0.0-cp39-abi3-win_amd64.whl (3.1 MB)
# Installing collected packages: typesense, cryptography, pdfminer.six
# Successfully installed cryptography-43.0.0 pdfminer.six-20240706 typesense-0.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz  # PyMuPDF
import os
import nltk
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import numpy as np

# Download French stopwords if not already downloaded
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\trabe\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def extract_text_from_multiple_pdfs(folder_path):
    all_text_data = {}

    # Get all PDF files in the folder
    pdf_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.pdf')]

    for pdf_path in pdf_files:
        pdf_document = fitz.open(pdf_path)
        pdf_name = os.path.basename(pdf_path)
        text_data = []
        
        for page_num in range(pdf_document.page_count):
            page = pdf_document[page_num]
            text = page.get_text("text")
            text_data.append(text)
        
        all_text_data[pdf_name] = text_data
    
    return all_text_data

# Example usage
folder_path = "french"  # Path to your folder containing the PDFs
extracted_texts = extract_text_from_multiple_pdfs(folder_path)

# %%
def extract_keywords_tfidf(documents, top_n=5):
    # Initialize the French stopwords
    french_stopwords = list(set(stopwords.words('french')))  # Convert to list

    # Use TF-IDF Vectorizer to extract keywords
    tfidf_vectorizer = TfidfVectorizer(max_df=0.85, stop_words=french_stopwords, max_features=10000)
    tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
    feature_names = tfidf_vectorizer.get_feature_names_out()
    
    # Extract keywords for each document
    keywords_list = []
    for i in range(tfidf_matrix.shape[0]):
        tfidf_scores = tfidf_matrix[i].T.todense()
        tfidf_scores = np.array(tfidf_scores).flatten()
        top_keywords_indices = tfidf_scores.argsort()[-top_n:]
        top_keywords = [feature_names[j] for j in top_keywords_indices]
        keywords_list.append(top_keywords)
    
    return keywords_list

# %%
# Prepare the documents (all pages of all PDFs)
documents = []
for pdf_name, pages in extracted_texts.items():
    documents.extend(pages)

# Extract keywords using TF-IDF
keywords_list = extract_keywords_tfidf(documents)

# Display extracted keywords for each page
for i, keywords in enumerate(keywords_list):
    print(f"Document {i+1} Keywords: {', '.join(keywords)}")
# Out:
# Document 1 Keywords: déstructurer, œuvre, santé, guide, pratique
# Document 2 Keywords: ministre, 2017f, hp5, cat, 660
# Document 3 Keywords: durant, santé, guide, expérience, renseignements
# Document 4 Keywords: favoriserez, additionnelles, croissance, collation, prénatale
# Document 5 Keywords: légumes, privilégiez, matières, substituts, grasses
# Document 6 Keywords: prénatale, poids, imc, livres, kg
# Document 7 Keywords: comme, non, site, gc, pasteurisés
# Document 8 Keywords: vertébrale, colonne, crâne, acide, folique
# Document 9 Keywords: tube, neural, acide, folique, atn
# Document 10 Keywords: santé, décelées, acide, folique, atn
# Document 11 Keywords: bon, durant, ensemble, etcaf, alcool
# Document 12 Keywords: bébé, sait, quantité, développement, alcool
# Document 13 Keywords: biologique, boire, durant, alcool, etcaf
# Document 14 Keywords: aide, durant, améliore, physique, activité
# Document 15 Keywords: commencez, activités, augmentez, physique, activité
# Document 16 Keywords: active, charges, haltères, physique, activité
# Document 17 Keywords: site, physique, canada, ca, activité
# Document 18 Keywords: bébé, tabagisme, fumée, juste, fumez
# Document 19 Keywords: cancer, smsn, tabagisme, secondaire, fumée
# Document 20 Keywords: bébé, tabagisme, arrêter, fumée, fumer
# Document 21 Keywords: ca, fumée, renoncement, www, fumer
# Document 22 Keywords: soin, santé, pérodontaux, gencives, buccodentaire
# Document 23 Keywords: nettoyage, endommager, buccodentaire, carie, dents
# Document 24 Keywords: jonction, dentiste, dentaire, dents, gencives
# Document 25 Keywords: calcium, canadienne, buccodentaire, www, ca
# Document 26 Keywords: corporels, santé, pensées, vais, émotionnelle
# Document 27 Keywords: 24, évitez, symptômes, sentirez, stress
# Document 28 Keywords: contrariée, santé, courantes, émotionnelle, humeur
# Document 29 Keywords: santé, canada, relations, sexuelles, ni
# Document 30 Keywords: mois, dix, odeurs, vomissements, nausées
# Document 31 Keywords: enrichies, soja, vitamine, dents, calcium
# Document 32 Keywords: comme, tasses, tisanes, caféine, écorce
# Document 33 Keywords: corps, énormément, tièdes, constipation, laxatifs
# Document 34 Keywords: 220, manquent, réaction, assurer, fer
# Document 35 Keywords: pommes, substituts, fruits, légumes, boîte
# Document 36 Keywords: environ, réduire, liquides, enflure, pieds
# Document 37 Keywords: repas, étendez, antiacides, brûlures, estomac
# Document 38 Keywords: rafraîchit, beaucoup, buvez, transporte, eau
# Document 39 Keywords: plus, santé, parents, devez, nouveaux
# Document 40 Keywords: prénatale, www, gc, ca, pcnp
# Document 41 Keywords: bienfaits, maternel, bébé, aliment, allaitement
# Document 42 Keywords: enfants, vaccins, protection, vaccin, vaccination
# Document 43 Keywords: désirez, désireuses, désire, détacher, œuvre
# Document 44 Keywords: déstabilisées, œuvre, canada, ca, sante
# Document 45 Keywords: maternités, participation, nalzaro, méditations, adeline
# Document 46 Keywords: sœur, fabrication, sophie, marie, direction
# Document 47 Keywords: maternités, participation, nalzaro, méditations, adeline
# Document 48 Keywords: désirez, désireuses, désire, détacher, œuvre
# Document 49 Keywords: 107, 111, préface, prénoms, mois
# Document 50 Keywords: fils, créé, amour, joie, dieu
# Document 51 Keywords: peur, joie, mystère, vie, dieu
# Document 52 Keywords: désirez, désireuses, désire, détacher, œuvre
# Document 53 Keywords: image, homme, is, genèse, créa
# Document 54 Keywords: dieu, marie, être, dès, là
# Document 55 Keywords: vie, petite, puisse, esprit, accueillir
# Document 56 Keywords: petite, dieu, reste, cellules, grappe
# Document 57 Keywords: premier, vie, confiance, seigneur, vivre
# Document 58 Keywords: alors, cœur, mé, dit, noter
# Document 59 Keywords: confiance, seigneur, là, joie, instant
# Document 60 Keywords: vêtu, lation, tissent, semaine, petit
# Document 61 Keywords: étonner, merveille, chiara, vie, seigneur
# Document 62 Keywords: désirez, désireuses, désire, détacher, œuvre
# Document 63 Keywords: seigneur, 49, isaïe, façonné, is
# Document 64 Keywords: hypersensibilité, semaine, saint, petit, prier
# Document 65 Keywords: 21, elles, amour, vis, connais
# Document 66 Keywords: tir, fin, taux, semaine, hormone
# Document 67 Keywords: persévérer, avoue, toute, parfois, difficile
# Document 68 Keywords: retourner, sépare, amie, semaine, mains
# Document 69 Keywords: quitte, nageant, toujours, yeux, ressens
# Document 70 Keywords: ébauchés, lettres, viens, semaine, autre
# Document 71 Keywords: petit, seul, joie, trésor, amour
# Document 72 Keywords: simplicité, découvrirez, conﬁ, ttc, livre
# Document 73 Keywords: déséquilibrée, alimentation, durant, allaitement, période
# Document 74 Keywords: optimal, alimentation, enfant, avant, optimale
# Document 75 Keywords: bifida, spina, durant, acide, folique
# Document 76 Keywords: prise, recommandée, kg, sg, poids
# Document 77 Keywords: tée, recommandations, alimentation, quotidiennement, équilibrée
# Document 78 Keywords: produits, poisson, céréales, portion, fromage
# Document 79 Keywords: café, cuil, boissons, jour, huile
# Document 80 Keywords: apport, vitamines, sels, acide, folique
# Document 81 Keywords: végétarienne, végétalienne, alimentation, gras, poissons
# Document 82 Keywords: dioxine, toxoplasma, semaine, foie, thon
# Document 83 Keywords: crue, légumes, être, contaminer, infection
# Document 84 Keywords: cru, base, mangez, dure, evitez
# Document 85 Keywords: tons, inter, épanouie, souhai, alimentation
# Document 86 Keywords: 14, optimale, alimentation, durant, allaitement
# Document 87 Keywords: rant, décou, alimentation, enfant, maternel
# Document 88 Keywords: part, brochure, durant, équilibrée, allaitement
# Document 89 Keywords: équilibrée, acides, oméga, pyramide, quotidiennement
# Document 90 Keywords: céréales, vitamine, complètes, fruits, coque
# Document 91 Keywords: semaine, ex, max, huile, fois
# Document 92 Keywords: donc, mère, alimentation, allaitement, kcal
# Document 93 Keywords: thon, plomb, 130, composés, dioxine
# Document 94 Keywords: alimentation, lait, maternel, graisses, mère
# Document 95 Keywords: office, www, société, ch, suisse
# Document 96 Keywords: publication, fédéral, office, berne, ofsp
# Document 97 Keywords: consultations, hygiène, être, gynécologue, doivent
# Document 98 Keywords: consulter, être, accouchement, mouvements, actifs
# Document 99 Keywords: 56, cabinet, gynecologie, obstetrique, anesthésie
# Document 100 Keywords: création, comité, 1011, pédagogique, éditorial
# Document 101 Keywords: propres, 12, 10, vitamine, iv
# Document 102 Keywords: vi, ramadan, 18, 14, 13
# Document 103 Keywords: fœtale, adaptation, maternelle, connaître, physiologiques
# Document 104 Keywords: subvenir, répondront, fœtus, besoins, nutriments
# Document 105 Keywords: métabolisme, apport, 000, énergétique, kcal
# Document 106 Keywords: lipides, protéines, mg, fer, apport
# Document 107 Keywords: calcium, intestinale, anémie, ferritine, absorption
# Document 108 Keywords: apporte, fluor, systématique, administration, µg
# Document 109 Keywords: supplémentation, couverts, apports, périconceptionnelle, vitamine
# Document 110 Keywords: uvmaf, 700, prise, poids, kg
# Document 111 Keywords: diabète, prévention, alcool, carences, iv
# Document 112 Keywords: laver, faut, soigneusement, lavage, crus
# Document 113 Keywords: ramadan, organisme, lourd, repas, jeûne
# Document 114 Keywords: favorisent, saccharose, repas, sucre, tartines
# Document 115 Keywords: laitage, légumes, fruit, semaine, fois
# Document 116 Keywords: minérale, frac12, litres, portion, eau
# Document 117 Keywords: vi, collège, has, abréviations, 18
# Document 118 Keywords: désirs, pratique, médicaments, pharmaciens, fiche
# Document 119 Keywords: médicaments, risque, distance, fœtotoxiques, effets
# Document 120 Keywords: exposées, malformation, cliniques, animal, données
# Document 121 Keywords: www, ansm, médicaments, crpv, fr
# Document 122 Keywords: réévaluer, crpv, médicaments, traitement, patiente
# Document 123 Keywords: médicaments, médicament, ains, rappeler, patiente
# Document 124 Keywords: enceinte, division, nutrition, région, pacifique
# Document 125 Keywords: division, 2020, calédonie, nouméa, pacifique
# Document 126 Keywords: traduction, pacifique, cps, communauté, oceania
# Document 127 Keywords: 18, trimestre, bonne, 19, 17
# Document 128 Keywords: leurs, karen, pacifique, nutrition, fidji
# Document 129 Keywords: région, carences, enfant, mère, nutrition
# Document 130 Keywords: nutritionnelles, santé, nations, unies, recommandations
# Document 131 Keywords: promouvoir, mère, aliments, santé, nutritionnels
# Document 132 Keywords: enceintes, énergétiques, femmes, nutriments, aliments
# Document 133 Keywords: salades, compris, kg, m², poids
# Document 134 Keywords: mère, dates, conservés, future, aliments
# Document 135 Keywords: tomate, types, salade, menus, équilibrés
# Document 136 Keywords: calcium, journalier, supplémentaires, 450, calories
# Document 137 Keywords: aliments, légumes, portions, portion, tasse
# Document 138 Keywords: tasse, environ, privilégier, complet, aliments
# Document 139 Keywords: imc, prise, semaine, poids, kg
# Document 140 Keywords: découper, éviter, restes, aliments, nettoyer
# Document 141 Keywords: anémie, acide, mère, future, milligrammes
# Document 142 Keywords: trimestre, faut, maux, section, prise
# Document 143 Keywords: section, mère, trimestre, future, prise
# Document 144 Keywords: mère, trimestre, insister, prise, future
# Document 145 Keywords: trop, mal, aliments, conseillé, repas
# Document 146 Keywords: risque, glycémie, gestationnel, hypertension, diabète
# Document 147 Keywords: exclusif, allaitement, nutriments, maîtriser, mères
# Document 148 Keywords: aidée, via, guidelines, poisson, pacifique
# Document 149 Keywords: calcium, prise, portions, supplémentation, aliments
# Document 150 Keywords: gros, pratiquer, diabète, gestationnel, repas
# Document 151 Keywords: 2018, health, pacific, the, and
# Document 152 Keywords: for, 2018, and, of, 2017
# Document 153 Keywords: pacificdiets, private, facebook, enquiries, pacifique
# Document 154 Keywords: œuvre, lifestyle, samuelle, simard, photographie
# Document 155 Keywords: 76, 184, 118, 136, préparation
# Document 156 Keywords: prévue, fécondation, martin, mélissa, 29
# Document 157 Keywords: adaptations, repose, questionnements, expérience, vise
# Document 158 Keywords: cycles, menstruels, menstruation, cycle, menstruel
# Document 159 Keywords: interactions, fécondation, menstruel, cycle, ovulation
# Document 160 Keywords: ovulatoire, chance, ovule, fécondité, période
# Document 161 Keywords: séminales, millions, éjaculation, homme, spermatozoïdes
# Document 162 Keywords: ovaires, relie, col, vagin, utérus
# Document 163 Keywords: organe, pénis, canal, prostate, testicules
# Document 164 Keywords: couche, lieu, fécondation, ovule, spermatozoïde
# Document 165 Keywords: prévue, menstruation, dernière, date, semaines
# Document 166 Keywords: 31, tt, lennart, nilsson, fœtus
# Document 167 Keywords: menstruation, trimestre, battre, embryon, semaines
# Document 168 Keywords: doigts, formées, semaines, séparés, embryon
# Document 169 Keywords: trimestre, 14, 33, semaines, fœtus
# Document 170 Keywords: mouvements, 19, commencent, trimestre, semaines
# Document 171 Keywords: basse, sons, fœtus, cils, semaines
# Document 172 Keywords: fœtus, 42, trimestre, 36, semaines
# Document 173 Keywords: extérieurs, membranes, membrane, liquide, amniotique
# Document 174 Keywords: déchets, fœtus, ombilical, cordon, placenta
# Document 175 Keywords: désirez, détail, œuvre, liane, comeau
# Document 176 Keywords: janie, grondin, changements, physiques, 71
# Document 177 Keywords: être, légèrement, changements, cheveux, poils
# Document 178 Keywords: foncée, masque, peau, vergetures, hyperpigmentation
# Document 179 Keywords: envie, reins, vessie, peau, uriner
# Document 180 Keywords: utérus, estomac, bosses, seins, colostrum
# Document 181 Keywords: semaines, rectum, autour, utérus, intestin
# Document 182 Keywords: articulations, prise, graisse, réserves, poids
# Document 183 Keywords: gain, maternelles, 47, extravasculaires, répartition
# Document 184 Keywords: fringales, 500, lb, prise, poids
# Document 185 Keywords: femmes, changements, inconforts, transformation, corps
# Document 186 Keywords: femmes, tour, vivre, changements, émotions
# Document 187 Keywords: femmes, hésitez, attention, peuvent, commentaires
# Document 188 Keywords: implication, vivra, chez, vivent, dépression
# Document 189 Keywords: 53, touchez, 730, aider, relation
# Document 190 Keywords: part, couple, famille, enfants, relation
# Document 191 Keywords: demandant, bébé, pouvez, enfants, arrivée
# Document 192 Keywords: comme, limites, sexuel, sexuelles, désir
# Document 193 Keywords: its, amniotiques, orgasme, relations, sexuelles
# Document 194 Keywords: utilisez, crèmes, solaire, moustiques, écran
# Document 195 Keywords: huile, contenant, appliquer, épilation, bronzage
# Document 196 Keywords: activités, diabète, physiques, soulage, prévient
# Document 197 Keywords: modérée, mobilité, intensité, quotidien, activités
# Document 198 Keywords: avertira, empêchent, bascule, diminuez, activité
# Document 199 Keywords: physiques, faire, entraîner, activités, activité
# Document 200 Keywords: arrêter, aide, drogues, cigarettes, tabac
# Document 201 Keywords: abandon, augmente, jarrete, fumée, tabagisme
# Document 202 Keywords: cerveau, causer, dommages, troubles, alcool
# Document 203 Keywords: boissons, découvrir, profitez, alcoolisés, cocktails
# Document 204 Keywords: nuire, usage, fumé, nausées, cannabis
# Document 205 Keywords: aide, 2626, drogue, safera, drogues
# Document 206 Keywords: toxiques, produits, décapants, peintures, nettoyants
# Document 207 Keywords: attraper, chats, lavez, parasite, chat
# Document 208 Keywords: danger, code, programme, cnesst, travail
# Document 209 Keywords: déplacements, compagnie, avion, sécurité, ceinture
# Document 210 Keywords: zika, note, virus, étranger, voyage
# Document 211 Keywords: étranger, soins, coûteux, zika, virus
# Document 212 Keywords: 76, 116, manger, prévention, 103
# Document 213 Keywords: entiers, aliments, bien, repas, manger
# Document 214 Keywords: adapter, particuliers, conseils, fournissent, besoins
# Document 215 Keywords: brûlures, façon, permet, régulière, manger
# Document 216 Keywords: manger, autre, diminuer, fringales, appétit
# Document 217 Keywords: alimentaire, bref, catégories, aversions, aliments
# Document 218 Keywords: intégrer, couleur, fruits, légumes, légume
# Document 219 Keywords: fibres, sucre, choisissez, fruits, légumes
# Document 220 Keywords: énergie, riz, aliments, grains, entiers
# Document 221 Keywords: protéinés, yogourt, produits, laitiers, lait
# Document 222 Keywords: contiennent, lactose, enrichies, boissons, soya
# Document 223 Keywords: comme, variété, économiques, nourrissants, légumineuses
# Document 224 Keywords: contiennent, gras, protéines, poisson, gibier
# Document 225 Keywords: pâle, grammes, truite, conserve, thon
# Document 226 Keywords: morceaux, biscottes, fruits, tartinade, collations
# Document 227 Keywords: alimentation, marie, ève, 91, caplette
# Document 228 Keywords: éléments, fer, acide, folique, multivitamine
# Document 229 Keywords: bébé, enrichies, acide, folique, fer
# Document 230 Keywords: pois, aliments, végétale, origine, fer
# Document 231 Keywords: enrichies, sardines, yogourts, vitamine, calcium
# Document 232 Keywords: lin, graines, aliments, fibres, oméga
# Document 233 Keywords: hydrater, eau, ajoutant, nutritives, boissons
# Document 234 Keywords: ml, boissons, glacés, café, caféine
# Document 235 Keywords: preuves, cafeine, gingembre, ingrédients, tisanes
# Document 236 Keywords: particuliers, diabète, aliments, substituts, sucre
# Document 237 Keywords: manger, voir, multiple, plus, page
# Document 238 Keywords: détail, œuvre, pendant, alimentation, 102
# Document 239 Keywords: entreprendre, allergies, éléments, nutritifs, diète
# Document 240 Keywords: origine, aliments, prévention, infections, microbes
# Document 241 Keywords: cuisine, ml, vaisselle, eau, lavez
# Document 242 Keywords: température, dégeler, dégelées, thermoguide, réfrigérateur
# Document 243 Keywords: cuire, prêts, température, décongélation, aliments
# Document 244 Keywords: 160, bœuf, veau, porc, ex
# Document 245 Keywords: table, saucisses, restants, 165, 74
# Document 246 Keywords: bactérie, contracter, toxoplasmose, infection, listériose
# Document 247 Keywords: cuits, cuisson, aliments, listériose, bactérie
# Document 248 Keywords: pâtés, choix, ex, réchauffées, viandes
# Document 249 Keywords: fumés, ex, fruits, poisson, mer
# Document 250 Keywords: crus, fruits, cuits, pasteurisés, œufs
# Document 251 Keywords: pâte, faits, fromages, lait, pasteurisé
# Document 252 Keywords: saine, alimentation, aliments, ca, rappels
# Document 253 Keywords: olo, banques, visitez, connaître, clsc
# Document 254 Keywords: 123, 119, 132, 118, suivi
# Document 255 Keywords: clsc, cliniques, infirmières, professionnels, services
# Document 256 Keywords: équipe, santé, accompagnante, suivi, accompagnantes
# Document 257 Keywords: diriger, collabore, vers, services, clsc
# Document 258 Keywords: rencontres, social, accès, services, info
# Document 259 Keywords: analyses, voir, page, régulières, consultations
# Document 260 Keywords: rendez, suivi, questions, consultation, semaines
# Document 261 Keywords: nature, problèmes, première, consultation, quelles
# Document 262 Keywords: cœur, semaines, vérifiera, dépistage, examen
# Document 263 Keywords: analyses, prises, rh, si, urine
# Document 264 Keywords: bactérie, its, vérifier, échographie, dépistage
# Document 265 Keywords: programme, trisomie, tests, prénatal, dépistage
# Document 266 Keywords: élevée, probabilité, biochimique, trisomie, test
# Document 267 Keywords: passer, dépistage, test, amniocentèse, tests
# Document 268 Keywords: radiographie, optométriste, dentiste, radiographies, vision
# Document 269 Keywords: maladies, contre, coqueluche, grippe, vaccin
# Document 270 Keywords: rubéole, contact, cinquième, rougeole, maladie
# Document 271 Keywords: contagieuses, personne, maladie, si, varicelle
# Document 272 Keywords: conjugale, 151, 137, 136, 168
# Document 273 Keywords: vente, libre, naturels, prescrits, médicaments
# Document 274 Keywords: vérifier, pris, vente, libre, médicaments
# Document 275 Keywords: certains, produits, naturels, tisanes, plantes
# Document 276 Keywords: qualité, sommeil, apport, page, voir
# Document 277 Keywords: repas, urine, nausées, manger, vomissements
# Document 278 Keywords: jambes, muscles, crampes, accumulation, douleur
# Document 279 Keywords: tomates, repas, manger, symptômes, diminuer
# Document 280 Keywords: allez, augmentez, suppléments, hémorroïdes, constipation
# Document 281 Keywords: exerce, bains, appliquez, gonfler, constipation
# Document 282 Keywords: sang, anus, jambes, varices, enflure
# Document 283 Keywords: comprime, mains, nuit, ressentez, poignet
# Document 284 Keywords: voir, ligaments, support, genoux, dos
# Document 285 Keywords: 149, saignements, enflure, gencives, soie
# Document 286 Keywords: si, problèmes, courants, signaux, santé
# Document 287 Keywords: enflure, sévères, signaux, alarme, douleurs
# Document 288 Keywords: fausse, vaginaux, début, abondants, saignements
# Document 289 Keywords: douleurs, évaluation, après, évanouissements, saignement
# Document 290 Keywords: subit, douleurs, 38, température, fièvre
# Document 291 Keywords: aspirine, ibuprofène, md, mouvements, acétaminophène
# Document 292 Keywords: elles, prématuré, utérines, travail, contractions
# Document 293 Keywords: contractions, urine, ventre, sensation, douleur
# Document 294 Keywords: eaux, pertes, liquide, perte, amniotique
# Document 295 Keywords: perdez, quantité, serviette, liquide, pertes
# Document 296 Keywords: début, va, saignements, couche, fausse
# Document 297 Keywords: ans, rares, ectopique, couche, fausse
# Document 298 Keywords: couche, fausse, vivre, perte, deuil
# Document 299 Keywords: québécois, vécu, décès, parentale, deuil
# Document 300 Keywords: plus, risque, grossesses, hypertension, diabète
# Document 301 Keywords: régulier, exercice, clavardage, diabète, diabete
# Document 302 Keywords: bagage, côte, types, identiques, jumeaux
# Document 303 Keywords: malaises, plus, jumeaux, bébés, multiple
# Document 304 Keywords: contrôle, blesser, conflits, conjugale, violence
# Document 305 Keywords: verbale, peuvent, celle, 9010, violence
# Document 306 Keywords: françois, jean, 171, 179, dufour
# Document 307 Keywords: questionnez, raisons, allaiter, allaitement, décision
# Document 308 Keywords: allaités, allaité, moins, maladies, allaitement
# Document 309 Keywords: personnes, geste, débuts, apprend, allaitement
# Document 310 Keywords: jours, très, production, lait, seins
# Document 311 Keywords: maternel, montée, laiteuse, composition, lait
# Document 312 Keywords: heures, peau, bébé, signes, faim
# Document 313 Keywords: efficace, sein, tétées, bébé, succion
# Document 314 Keywords: sucette, lait, accessoires, allaitement, biberon
# Document 315 Keywords: temporaires, défis, solutions, difficultés, allaitement
# Document 316 Keywords: faire, bébé, rôle, allaitement, conjointe
# Document 317 Keywords: types, entourage, intention, ressources, allaitement
# Document 318 Keywords: allaitement, ressources, 948, québec, org
# Document 319 Keywords: gratifiant, difficultés, fois, allaitement, expérience
# Document 320 Keywords: 186, préparation, stéphanie, lieu, naissance
# Document 321 Keywords: permettent, lieux, accouchement, lieu, naissance
# Document 322 Keywords: carnet, carte, confortables, papiers, vêtements
# Document 323 Keywords: suggestions, partenaire, couches, bain, vêtements
# Document 324 Keywords: vaginale, avac, accouchement, vaginal, césarienne
# Document 325 Keywords: préparation, césarienne, voie, accouchement, vaginale
# Document 326 Keywords: bébé, bas, siège, technique, version
# Document 327 Keywords: accouchement, vaginal, césarienne, présentation, siège
# Document 328 Keywords: accouchement, préparation, 192, morand, dominic
# Document 329 Keywords: lieu, modèles, plan, souhaits, naissance
# Document 330 Keywords: questions, naissance, plan, rappelez, accouchement
# Document 331 Keywords: apprivoiser, douleur, page, voir, souhaitez
# Document 332 Keywords: quelles, lieu, cohabitation, souhaitez, interventions
# Document 333 Keywords: naît, nourrir, bébé, naissance, souhaitez
# Document 334 Keywords: maison, parents, repas, amis, arrivée
# Document 335 Keywords: familial, calme, espace, créer, cocon
# Document 336 Keywords: services, préparer, arrivée, propose, maison
# Document 337 Keywords: accouchement, préparation, estrela, sandra, 201
# Document 338 Keywords: santé, guide, nutrition, mangeant, bougeant
# Document 339 Keywords: université, afssa, pr, dr, paris
# Document 340 Keywords: introduction, glossaire, sommaire, gérer, page
# Document 341 Keywords: dienne, quoti, contraintes, conseils, trouverez
# Document 342 Keywords: élément, aborde, attentive, faut, hygiène
# Document 343 Keywords: médecin, alimentaires, compléments, sous, nutriments
# Document 344 Keywords: fromage, jus, goûter, éviter, verre
# Document 345 Keywords: sautés, sandwich, asiatique, maison, crudités
# Document 346 Keywords: fruit, faim, riz, pâtes, repas
# Document 347 Keywords: repas, calent, céréalière, très, pain
# Document 348 Keywords: sage, très, mangeons, variée, folates
# Document 349 Keywords: pois, fromages, pommes, forte, folates
# Document 350 Keywords: laitiers, fromage, produits, soja, calcium
# Document 351 Keywords: soleil, thon, saumon, essentiellement, vitamine
# Document 352 Keywords: si, absorption, origine, vitamine, fer
# Document 353 Keywords: iodé, supplément, iode, crustacés, médicamenteux
# Document 354 Keywords: nutritionnels, médicamenteux, alimentation, vitamine, besoins
# Document 355 Keywords: prendre, collations, repas, nausées, trop
# Document 356 Keywords: constipation, fibres, acides, repas, astuces
# Document 357 Keywords: moitié, moyenne, kg, prise, poids
# Document 358 Keywords: notam, phlébites, prise, poids, régimes
# Document 359 Keywords: ture, bouger, activité, favorise, gymnastique
# Document 360 Keywords: pratiqués, équitation, évitez, sport, sports
# Document 361 Keywords: lavez, touché, mains, après, bien
# Document 362 Keywords: point, froide, zone, congélateur, réfrigérateur
# Document 363 Keywords: type, toxoplasmose, listériose, fromages, croûte
# Document 364 Keywords: crue, protégée, si, viande, toxoplasmose
# Document 365 Keywords: thé, foie, boissons, café, caféine
# Document 366 Keywords: enrichis, produits, phytostérols, base, soja
# Document 367 Keywords: enfant, fumer, fumé, tabac, alcool
# Document 368 Keywords: alimentaires, alimentaire, arachide, allergies, allergie
# Document 369 Keywords: enfant, inpes, sites, naissance, maternel
# Document 370 Keywords: fr, 38, repères, allaitez, allaitiez
# Document 371 Keywords: fibres, glucides, lipides, énergie, aliment
# Document 372 Keywords: végétaux, organisme, substances, soja, indispensables
# Document 373 Keywords: désiré, détaillée, 36, bloc, notes
# Document 374 Keywords: déstabilisées, œuvre, guide, nutrition, 37
# Document 375 Keywords: pêche, produits, jour, consommation, limiter
# Document 376 Keywords: privilégier, gras, sucrées, variété, limiter
# Document 377 Keywords: 55, 29915, 43515, collection, 250
# Document 378 Keywords: depuis, chapelle, enfantement, dame, neuvaine
# Document 379 Keywords: jour, toutes, dame, intentions, prions
# Document 380 Keywords: time, resource, can, but, fast
# Document 381 Keywords: entirely, the, business, to, you

# %%
# Delete the collection if it already exists
try:
    client.collections['pdfs'].delete()
    print("Existing collection 'pdfs' deleted.")
except Exception as e:
    print(f"Could not delete collection: {e}")

# Define schema for Typesense collection
schema = {
    'name': 'pdfs',
    'fields': [
        {'name': 'pdf_name', 'type': 'string'},
        {'name': 'text', 'type': 'string'},
        {'name': 'keywords', 'type': 'string'},
        {'name': 'page_number', 'type': 'int32'},
        {'name': 'paragraph_number', 'type': 'int32'}
    ]
}

# Create the collection again
try:
    client.collections.create(schema)
    print("New collection 'pdfs' created.")
except Exception as e:
    print(f"Failed to create collection: {e}")
# Out:
# Existing collection 'pdfs' deleted.
# New collection 'pdfs' created.

# %%
def index_multiple_pdfs_data_tfidf(extracted_texts, keywords_list):
    doc_idx = 0
    for pdf_name, pages in extracted_texts.items():
        for page_num, text in enumerate(pages):
            keywords = ', '.join(keywords_list[doc_idx])
            document = {
                'pdf_name': pdf_name,
                'text': text,
                'keywords': keywords,  # Ensure keywords are included
                'page_number': page_num,
                'paragraph_number': 0  # Assume 0 as we are not splitting paragraphs further here
            }
            client.collections['pdfs'].documents.create(document)
            doc_idx += 1

# Index the text data from all PDFs
index_multiple_pdfs_data_tfidf(extracted_texts, keywords_list)

print("Indexing completed.")
# Out:
# Indexing completed.

# %%
# Test by querying the indexed data
print("Testing by querying:")
try:
    results = client.collections['pdfs'].documents.search({
        'q': 'nutrition prénatale',
        'query_by': 'text,keywords'
    })
    for hit in results['hits']:
        print(f"PDF: {hit['document']['pdf_name']}, Page: {hit['document']['page_number']}")
        print("Keywords:", hit['document']['keywords'])
        print(hit['document']['text'][:200], '...')  # Display first 200 characters
        print("-" * 80)
except Exception as e:
    print(f"Query failed: {e}")
# Out:
# Testing by querying:
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 39
# Keywords: prénatale, www, gc, ca, pcnp
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# 38
# Ressources
# RESSOURCES
# Grossesse en santé
# Canada.ca/sante
# Activité physique
# www.santepublique.gc.ca/guideap
# Guide des parents ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 5
# Keywords: prénatale, poids, imc, livres, kg
# 4
# La nutrition prénatale
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# Consultez le site Internet de Santé Canada pour savoir
# comment choisir des poissons qui contiennent peu ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 3
# Keywords: favoriserez, additionnelles, croissance, collation, prénatale
# 2
# La nutrition prénatale
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# La nutrition prénatale
# L’alimentation joue un rôle très important dans une grossesse en santé. Pour vous ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 6
# Keywords: comme, non, site, gc, pasteurisés
# La nutrition prénatale
# 5
# Y a-t-il des aliments à éviter durant
# ma grossesse ?
# Oui. Évitez les aliments suivants, qui pourraient être
# contaminés par des bactéries :
# 
#  poisson cru, comme les sushis ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 4
# Keywords: légumes, privilégiez, matières, substituts, grasses
# La nutrition prénatale
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# 3
# Les fruits et les légumes : indispensables
# !
# Les femmes enceintes doivent manger des fruits et des
# lé ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 2
# Keywords: durant, santé, guide, expérience, renseignements
# Le guide pratique d’une grossesse en santé
# Si vous êtes enceinte ou que vous prévoyez le devenir, ce guide est pour vous!
# La grossesse peut être une expérience merveilleuse, mais c’est aussi une pério ...
# --------------------------------------------------------------------------------
# PDF: Guide_nutrition_pour_la_femme_enceinte_region_Pacifique-1.pdf, Page: 6
# Keywords: nutritionnelles, santé, nations, unies, recommandations
# 2
# Guide nutrition pour la femme enceinte – région Pacifique
# Manuel à destination des professionnels de santé et des éducateurs
# La grossesse est un moment charnière pour encourager les futures mères à ...
# --------------------------------------------------------------------------------
# PDF: mv2022_s1_grossesse.pdf, Page: 98
# Keywords: saine, alimentation, aliments, ca, rappels
# 116
# Grossesse
# L’alimentation pendant la grossesse
# Pour en savoir plus
# Pour plus de renseignements sur la prévention
# des infections d’origine alimentaire, consultez le
# canadiensensante.gc.ca/alt/pdf/ ...
# --------------------------------------------------------------------------------
# PDF: Guide_nutrition_pour_la_femme_enceinte_region_Pacifique-1.pdf, Page: 28
# Keywords: for, 2018, and, of, 2017
# 24
# Guide nutrition pour la femme enceinte – région Pacifique
# Manuel à destination des professionnels de santé et des éducateurs
# 18. 	 Organisation mondiale de la Santé. Recommandations de l’OMS conce ...
# --------------------------------------------------------------------------------
# PDF: PNNS_grossesse.pdf, Page: 36
# Keywords: déstabilisées, œuvre, guide, nutrition, 37
# 37
# Le guide nutrition
# de la grossesse
#  ...
# --------------------------------------------------------------------------------

# %%
import os
os.environ["TORCH_DYNAMO_DISABLE"] = "1"

# %%
from sentence_transformers import SentenceTransformer

# Load the model
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# Test embedding extraction
try:
    text = "Votre texte en français ici."
    embedding = model.encode(text)
    print("Embedding shape:", embedding.shape)
except Exception as e:
    print("Error during embedding extraction:", e)
# Out:
# Embedding shape: (384,)

# %%
from transformers import AutoModel, AutoTokenizer
from sentence_transformers import SentenceTransformer, util
import torch

# Load a French-compatible model
# Example using a Mistral model (adjust model path as needed)
model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
model = SentenceTransformer(model_name)

# If using a LLaMA model or similar, you might load it like this:
# model_name = "path/to/llama/french/model"
# model = AutoModel.from_pretrained(model_name)
# tokenizer = AutoTokenizer.from_pretrained(model_name)

def get_embedding(text):
    # For Sentence-Transformers
    return model.encode(text, convert_to_tensor=True)

# Example usage
embedding = get_embedding("Votre texte en français ici.")
print(embedding.shape)  # Should return the shape of the embedding tensor
# Out:
# torch.Size([384])

# %%
def semantic_search(query, typesense_results):
    # Get the embedding of the query
    query_embedding = get_embedding(query)
    
    # Prepare the list to hold the results with their similarity scores
    search_results = []

    for hit in typesense_results['hits']:
        # Extract text from the Typesense result
        text = hit['document']['text']
        pdf_name = hit['document']['pdf_name']
        page_number = hit['document']['page_number']
        
        # Get the embedding of the document text
        text_embedding = get_embedding(text)
        
        # Compute the cosine similarity
        similarity = util.pytorch_cos_sim(query_embedding, text_embedding).item()
        
        # Store the result with the similarity score
        search_results.append((similarity, pdf_name, page_number, text))

    # Sort the results by similarity score in descending order
    search_results = sorted(search_results, key=lambda x: x[0], reverse=True)

    return search_results

# Perform Typesense search
print("Performing Typesense search...")
typesense_results = client.collections['pdfs'].documents.search({
    'q': 'nutrition prénatale',
    'query_by': 'text,keywords'
})

# Now perform semantic search using the Typesense results
query = "nutrition prénatale"
semantic_results = semantic_search(query, typesense_results)

# Display the top semantic search results
print(f"\nTop Semantic Search Results for '{query}':")
for similarity, pdf_name, page_number, text in semantic_results[:5]:  # Show top 5 results
    print(f"PDF: {pdf_name}, Page: {page_number + 1}, Similarity: {similarity:.4f}")
    print(text[:500], '...')  # Display first 200 characters of the text
    print("-" * 80)
# Out:
# Performing Typesense search...
#
# Top Semantic Search Results for 'nutrition prénatale':
# PDF: PNNS_grossesse.pdf, Page: 37, Similarity: 0.8558
# 37
# Le guide nutrition
# de la grossesse
#  ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 4, Similarity: 0.7323
# 2
# La nutrition prénatale
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# La nutrition prénatale
# L’alimentation joue un rôle très important dans une grossesse en santé. Pour vous assurer d’obtenir
# les vitamines, minéraux et nutriments dont vous et votre enfant à naître avez besoin, vous devez
# consommer des aliments de différentes sources. En mangeant sainement, vous vous sentirez mieux,
# vous aurez plus d’énergie et vous favoriserez une prise de poids saine. Vous contribu ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 5, Similarity: 0.7068
# La nutrition prénatale
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# 3
# Les fruits et les légumes : indispensables
# !
# Les femmes enceintes doivent manger des fruits et des
# légumes tous les jours. Les légumes et les fruits très colorés
# contiennent une plus grande quantité des vitamines dont
# vous et votre bébé avez besoin. Consommez chaque jour au
# moins un légume vert foncé et un légume orange. Préparez
# vos fruits et légumes avec le moins de matières grasses,
# de sucr ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 6, Similarity: 0.6784
# 4
# La nutrition prénatale
# Gouvernement du Canada  |  Le guide pratique d’une grossesse en santé
# Consultez le site Internet de Santé Canada pour savoir
# comment choisir des poissons qui contiennent peu de
# mercure afin que votre bébé et vous-même profitiez des
# bienfaits de cet aliment tout en minimisant les risques
# d’exposition au mercure.
# QUESTIONS COURANTES SUR LA
# NUTRITION PRÉNATALE
# Combien de kilos dois-je prendre
# durant ma grossesse ?
# Tout dépend du poids que vous aviez avant de devenir ...
# --------------------------------------------------------------------------------
# PDF: 64-03-16-1758-Sensible Guide to Healthy Pregnancy-FR-Web-final-v1.pdf, Page: 7, Similarity: 0.6736
# La nutrition prénatale
# 5
# Y a-t-il des aliments à éviter durant
# ma grossesse ?
# Oui. Évitez les aliments suivants, qui pourraient être
# contaminés par des bactéries :
# 
#  poisson cru, comme les sushis, huîtres, palourdes et
# moules crues;
# 
#  viande, volaille et fruits de mer et hot dogs crus
# ou pas assez cuits;
# 
#  charcuteries non séchées comme la mortadelle,
# le rosbif, le jambon et la poitrine de dinde;
# 
#  pâtés réfrigérés, viande à tartiner, fruits de
# mer fumés et réfrigérés;
# 
#  tous  ...
# --------------------------------------------------------------------------------
