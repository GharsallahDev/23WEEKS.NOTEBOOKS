# %% [markdown]
# # **Baby name generator**

# %% [markdown]
# The journey of parenthood is filled with many exciting milestones, one of the most cherished being the selection of a baby’s name. A name carries deep significance, often reflecting cultural heritage, personal preferences, and hopes for the future. However, the process of choosing the perfect name can be overwhelming, with countless options and factors to consider.
#
# To assist parents in this important decision, we have created a Baby Name Generator. This tool is designed to simplify and enhance the name selection process.

# %% [markdown]
# # **Importing Libraries**

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.7.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.44.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (2.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.26.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.14.0)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.24.6)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (9.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.15.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.15.1->sentence-transformers) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.44.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.24.6)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **Data Scraping**

# %% [markdown]
# To create a robust and culturally rich Baby Name Generator, we sourced our data from the website Incompetech. This platform provided a diverse collection of names, which we specifically filtered to focus on African names from various countries.
#
# Our goal was to curate a dataset that reflects the vast cultural heritage and linguistic diversity of Africa. For each name, we captured key attributes including:
#
# - **Gender**: Identifying whether the name is typically used for boys, girls.
#
# - **Meaning**: Providing the significance or symbolism behind the name, which is often rooted in the cultural and linguistic traditions of its origin.
# - **Origin**: Indicating the country or cultural background from which the name originates.
#
# This data collection ensures that parents using our Baby Name Generator have access to a wide array of names that are not only unique and meaningful but also deeply connected to African heritage.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Base URL of the site
base_url = "https://incompetech.com/named/multi.pl"

# Define categories
categories = [
    "African - Abaluhyan", "African - Akan", "African - American",
    "African - Bantu", "African - Botswana", "African - Egyptian",
    "African - Ethiopian", "African - Ewe", "African - Fanti", "African - Ghanian",
    "African - Hausa", "African - Ibo", "African - Kenyan", "African - Kikuyu",
    "African - Lesotho", "African - Lugandan", "African - Malawian",
    "African - Musoga", "African - Nguni", "African - Nigerian", "African - Ochi",
    "African - Rukonjo", "African - Runyoro", "African - Rutooro", "African - Rwandan",
    "African - Somalian", "African - Swahili", "African - Tanzanian", "African - Ugandan",
    "African - Xhosha", "African - Yoruba", "African - Yoruban", "African - Zimbabwe",
    "African - Zulu", "African - Zuni", "Arabic"
]

def scrape_data(category, gender, start_seed=0, increment=50):
    all_data = []
    seed = start_seed
    while True:
        print(f"Fetching data for {category} ({gender}) with seed {seed}...")
        
        params = {
            'sex': gender,
            'language': category,
            'method': 'contains',
            'name': '',
            'meaning': '',
            'seed': seed,
            'action': 'search'
        }
        
        response = requests.get(base_url, params=params)
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the specific table containing the names
        table = soup.find('table', {'cellspacing': '2', 'bgcolor': '#ddddd'})
        
        # Check if the table exists and has rows
        if not table or len(table.find_all('tr')) <= 1:  # Only header or no data
            print(f"No more data found for {category} ({gender}) at seed {seed}. Stopping seed increment.")
            break  # No more data to fetch, stop incrementing the seed
        
        rows = table.find_all('tr')[1:]  # Skip the header row
        
        for row in rows:
            cells = row.find_all('td')
            if len(cells) >= 4:  # Ensure at least 4 columns
                name = cells[0].text.strip()
                origin = cells[1].text.strip()
                sex = cells[2].text.strip()
                meaning = cells[3].text.strip()
                variations = cells[4].text.strip() if len(cells) > 4 else ""
                all_data.append({
                    'Category': category, 
                    'Gender': gender, 
                    'Name': name, 
                    'Origin': origin, 
                    'Sex': sex, 
                    'Meaning': meaning,
                    'Variations': variations
                })
        
        # Increment seed for the next page of data
        seed += increment
    
    return all_data

def main():
    all_data = []
    
    for gender in ['Male', 'Female']:
        for category in categories:
            print(f"\nStarting to scrape {category} for {gender} names...")
            data = scrape_data(category, gender)
            
            if data:
                print(f"Successfully scraped {len(data)} records for {category} ({gender}).")
            else:
                print(f"No data found for {category} ({gender}).")
            
            all_data.extend(data)
            print(f"Total records collected so far: {len(all_data)}")
    
    # Save to CSV
    df = pd.DataFrame(all_data)
    df.to_csv('african_names.csv', index=False)
    print("Data has been scraped and saved to 'african_names.csv'")

if __name__ == "__main__":
    main()
# Out:
# Starting to scrape African - Abaluhyan for Male names...
# Fetching data for African - Abaluhyan (Male) with seed 0...
# Fetching data for African - Abaluhyan (Male) with seed 50...
# No more data found for African - Abaluhyan (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Abaluhyan (Male).
# Total records collected so far: 1
#
# Starting to scrape African - Akan for Male names...
# Fetching data for African - Akan (Male) with seed 0...
# Fetching data for African - Akan (Male) with seed 50...
# No more data found for African - Akan (Male) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Akan (Male).
# Total records collected so far: 3
#
# Starting to scrape African - American for Male names...
# Fetching data for African - American (Male) with seed 0...
# Fetching data for African - American (Male) with seed 50...
# No more data found for African - American (Male) at seed 50. Stopping seed increment.
# Successfully scraped 7 records for African - American (Male).
# Total records collected so far: 10
#
# Starting to scrape African - Bantu for Male names...
# Fetching data for African - Bantu (Male) with seed 0...
# No more data found for African - Bantu (Male) at seed 0. Stopping seed increment.
# No data found for African - Bantu (Male).
# Total records collected so far: 10
#
# Starting to scrape African - Botswana for Male names...
# Fetching data for African - Botswana (Male) with seed 0...
# Fetching data for African - Botswana (Male) with seed 50...
# No more data found for African - Botswana (Male) at seed 50. Stopping seed increment.
# Successfully scraped 7 records for African - Botswana (Male).
# Total records collected so far: 17
#
# Starting to scrape African - Egyptian for Male names...
# Fetching data for African - Egyptian (Male) with seed 0...
# Fetching data for African - Egyptian (Male) with seed 50...
# No more data found for African - Egyptian (Male) at seed 50. Stopping seed increment.
# Successfully scraped 12 records for African - Egyptian (Male).
# Total records collected so far: 29
#
# Starting to scrape African - Ethiopian for Male names...
# Fetching data for African - Ethiopian (Male) with seed 0...
# Fetching data for African - Ethiopian (Male) with seed 50...
# No more data found for African - Ethiopian (Male) at seed 50. Stopping seed increment.
# Successfully scraped 6 records for African - Ethiopian (Male).
# Total records collected so far: 35
#
# Starting to scrape African - Ewe for Male names...
# Fetching data for African - Ewe (Male) with seed 0...
# Fetching data for African - Ewe (Male) with seed 50...
# No more data found for African - Ewe (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Ewe (Male).
# Total records collected so far: 36
#
# Starting to scrape African - Fanti for Male names...
# Fetching data for African - Fanti (Male) with seed 0...
# Fetching data for African - Fanti (Male) with seed 50...
# No more data found for African - Fanti (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Fanti (Male).
# Total records collected so far: 37
#
# Starting to scrape African - Ghanian for Male names...
# Fetching data for African - Ghanian (Male) with seed 0...
# Fetching data for African - Ghanian (Male) with seed 50...
# No more data found for African - Ghanian (Male) at seed 50. Stopping seed increment.
# Successfully scraped 37 records for African - Ghanian (Male).
# Total records collected so far: 74
#
# Starting to scrape African - Hausa for Male names...
# Fetching data for African - Hausa (Male) with seed 0...
# No more data found for African - Hausa (Male) at seed 0. Stopping seed increment.
# No data found for African - Hausa (Male).
# Total records collected so far: 74
#
# Starting to scrape African - Ibo for Male names...
# Fetching data for African - Ibo (Male) with seed 0...
# Fetching data for African - Ibo (Male) with seed 50...
# No more data found for African - Ibo (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Ibo (Male).
# Total records collected so far: 75
#
# Starting to scrape African - Kenyan for Male names...
# Fetching data for African - Kenyan (Male) with seed 0...
# Fetching data for African - Kenyan (Male) with seed 50...
# No more data found for African - Kenyan (Male) at seed 50. Stopping seed increment.
# Successfully scraped 11 records for African - Kenyan (Male).
# Total records collected so far: 86
#
# Starting to scrape African - Kikuyu for Male names...
# Fetching data for African - Kikuyu (Male) with seed 0...
# Fetching data for African - Kikuyu (Male) with seed 50...
# No more data found for African - Kikuyu (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Kikuyu (Male).
# Total records collected so far: 87
#
# Starting to scrape African - Lesotho for Male names...
# Fetching data for African - Lesotho (Male) with seed 0...
# Fetching data for African - Lesotho (Male) with seed 50...
# No more data found for African - Lesotho (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Lesotho (Male).
# Total records collected so far: 88
#
# Starting to scrape African - Lugandan for Male names...
# Fetching data for African - Lugandan (Male) with seed 0...
# Fetching data for African - Lugandan (Male) with seed 50...
# No more data found for African - Lugandan (Male) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Lugandan (Male).
# Total records collected so far: 90
#
# Starting to scrape African - Malawian for Male names...
# Fetching data for African - Malawian (Male) with seed 0...
# Fetching data for African - Malawian (Male) with seed 50...
# No more data found for African - Malawian (Male) at seed 50. Stopping seed increment.
# Successfully scraped 36 records for African - Malawian (Male).
# Total records collected so far: 126
#
# Starting to scrape African - Musoga for Male names...
# Fetching data for African - Musoga (Male) with seed 0...
# No more data found for African - Musoga (Male) at seed 0. Stopping seed increment.
# No data found for African - Musoga (Male).
# Total records collected so far: 126
#
# Starting to scrape African - Nguni for Male names...
# Fetching data for African - Nguni (Male) with seed 0...
# Fetching data for African - Nguni (Male) with seed 50...
# No more data found for African - Nguni (Male) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Nguni (Male).
# Total records collected so far: 128
#
# Starting to scrape African - Nigerian for Male names...
# Fetching data for African - Nigerian (Male) with seed 0...
# Fetching data for African - Nigerian (Male) with seed 50...
# Fetching data for African - Nigerian (Male) with seed 100...
# No more data found for African - Nigerian (Male) at seed 100. Stopping seed increment.
# Successfully scraped 97 records for African - Nigerian (Male).
# Total records collected so far: 225
#
# Starting to scrape African - Ochi for Male names...
# Fetching data for African - Ochi (Male) with seed 0...
# Fetching data for African - Ochi (Male) with seed 50...
# No more data found for African - Ochi (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Ochi (Male).
# Total records collected so far: 226
#
# Starting to scrape African - Rukonjo for Male names...
# Fetching data for African - Rukonjo (Male) with seed 0...
# Fetching data for African - Rukonjo (Male) with seed 50...
# No more data found for African - Rukonjo (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Rukonjo (Male).
# Total records collected so far: 227
#
# Starting to scrape African - Runyoro for Male names...
# Fetching data for African - Runyoro (Male) with seed 0...
# Fetching data for African - Runyoro (Male) with seed 50...
# No more data found for African - Runyoro (Male) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Runyoro (Male).
# Total records collected so far: 228
#
# Starting to scrape African - Rutooro for Male names...
# Fetching data for African - Rutooro (Male) with seed 0...
# Fetching data for African - Rutooro (Male) with seed 50...
# No more data found for African - Rutooro (Male) at seed 50. Stopping seed increment.
# Successfully scraped 3 records for African - Rutooro (Male).
# Total records collected so far: 231
#
# Starting to scrape African - Rwandan for Male names...
# Fetching data for African - Rwandan (Male) with seed 0...
# Fetching data for African - Rwandan (Male) with seed 50...
# No more data found for African - Rwandan (Male) at seed 50. Stopping seed increment.
# Successfully scraped 3 records for African - Rwandan (Male).
# Total records collected so far: 234
#
# Starting to scrape African - Somalian for Male names...
# Fetching data for African - Somalian (Male) with seed 0...
# No more data found for African - Somalian (Male) at seed 0. Stopping seed increment.
# No data found for African - Somalian (Male).
# Total records collected so far: 234
#
# Starting to scrape African - Swahili for Male names...
# Fetching data for African - Swahili (Male) with seed 0...
# Fetching data for African - Swahili (Male) with seed 50...
# Fetching data for African - Swahili (Male) with seed 100...
# No more data found for African - Swahili (Male) at seed 100. Stopping seed increment.
# Successfully scraped 51 records for African - Swahili (Male).
# Total records collected so far: 285
#
# Starting to scrape African - Tanzanian for Male names...
# Fetching data for African - Tanzanian (Male) with seed 0...
# Fetching data for African - Tanzanian (Male) with seed 50...
# No more data found for African - Tanzanian (Male) at seed 50. Stopping seed increment.
# Successfully scraped 4 records for African - Tanzanian (Male).
# Total records collected so far: 289
#
# Starting to scrape African - Ugandan for Male names...
# Fetching data for African - Ugandan (Male) with seed 0...
# Fetching data for African - Ugandan (Male) with seed 50...
# No more data found for African - Ugandan (Male) at seed 50. Stopping seed increment.
# Successfully scraped 13 records for African - Ugandan (Male).
# Total records collected so far: 302
#
# Starting to scrape African - Xhosha for Male names...
# Fetching data for African - Xhosha (Male) with seed 0...
# No more data found for African - Xhosha (Male) at seed 0. Stopping seed increment.
# No data found for African - Xhosha (Male).
# Total records collected so far: 302
#
# Starting to scrape African - Yoruba for Male names...
# Fetching data for African - Yoruba (Male) with seed 0...
# Fetching data for African - Yoruba (Male) with seed 50...
# No more data found for African - Yoruba (Male) at seed 50. Stopping seed increment.
# Successfully scraped 11 records for African - Yoruba (Male).
# Total records collected so far: 313
#
# Starting to scrape African - Yoruban for Male names...
# Fetching data for African - Yoruban (Male) with seed 0...
# Fetching data for African - Yoruban (Male) with seed 50...
# No more data found for African - Yoruban (Male) at seed 50. Stopping seed increment.
# Successfully scraped 8 records for African - Yoruban (Male).
# Total records collected so far: 321
#
# Starting to scrape African - Zimbabwe for Male names...
# Fetching data for African - Zimbabwe (Male) with seed 0...
# Fetching data for African - Zimbabwe (Male) with seed 50...
# No more data found for African - Zimbabwe (Male) at seed 50. Stopping seed increment.
# Successfully scraped 18 records for African - Zimbabwe (Male).
# Total records collected so far: 339
#
# Starting to scrape African - Zulu for Male names...
# Fetching data for African - Zulu (Male) with seed 0...
# Fetching data for African - Zulu (Male) with seed 50...
# No more data found for African - Zulu (Male) at seed 50. Stopping seed increment.
# Successfully scraped 3 records for African - Zulu (Male).
# Total records collected so far: 342
#
# Starting to scrape African - Zuni for Male names...
# Fetching data for African - Zuni (Male) with seed 0...
# No more data found for African - Zuni (Male) at seed 0. Stopping seed increment.
# No data found for African - Zuni (Male).
# Total records collected so far: 342
#
# Starting to scrape Arabic for Male names...
# Fetching data for Arabic (Male) with seed 0...
# Fetching data for Arabic (Male) with seed 50...
# Fetching data for Arabic (Male) with seed 100...
# Fetching data for Arabic (Male) with seed 150...
# Fetching data for Arabic (Male) with seed 200...
# Fetching data for Arabic (Male) with seed 250...
# Fetching data for Arabic (Male) with seed 300...
# Fetching data for Arabic (Male) with seed 350...
# No more data found for Arabic (Male) at seed 350. Stopping seed increment.
# Successfully scraped 346 records for Arabic (Male).
# Total records collected so far: 688
#
# Starting to scrape African - Abaluhyan for Female names...
# Fetching data for African - Abaluhyan (Female) with seed 0...
# No more data found for African - Abaluhyan (Female) at seed 0. Stopping seed increment.
# No data found for African - Abaluhyan (Female).
# Total records collected so far: 688
#
# Starting to scrape African - Akan for Female names...
# Fetching data for African - Akan (Female) with seed 0...
# No more data found for African - Akan (Female) at seed 0. Stopping seed increment.
# No data found for African - Akan (Female).
# Total records collected so far: 688
#
# Starting to scrape African - American for Female names...
# Fetching data for African - American (Female) with seed 0...
# Fetching data for African - American (Female) with seed 50...
# No more data found for African - American (Female) at seed 50. Stopping seed increment.
# Successfully scraped 3 records for African - American (Female).
# Total records collected so far: 691
#
# Starting to scrape African - Bantu for Female names...
# Fetching data for African - Bantu (Female) with seed 0...
# Fetching data for African - Bantu (Female) with seed 50...
# No more data found for African - Bantu (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Bantu (Female).
# Total records collected so far: 692
#
# Starting to scrape African - Botswana for Female names...
# Fetching data for African - Botswana (Female) with seed 0...
# Fetching data for African - Botswana (Female) with seed 50...
# No more data found for African - Botswana (Female) at seed 50. Stopping seed increment.
# Successfully scraped 5 records for African - Botswana (Female).
# Total records collected so far: 697
#
# Starting to scrape African - Egyptian for Female names...
# Fetching data for African - Egyptian (Female) with seed 0...
# Fetching data for African - Egyptian (Female) with seed 50...
# No more data found for African - Egyptian (Female) at seed 50. Stopping seed increment.
# Successfully scraped 14 records for African - Egyptian (Female).
# Total records collected so far: 711
#
# Starting to scrape African - Ethiopian for Female names...
# Fetching data for African - Ethiopian (Female) with seed 0...
# Fetching data for African - Ethiopian (Female) with seed 50...
# No more data found for African - Ethiopian (Female) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Ethiopian (Female).
# Total records collected so far: 713
#
# Starting to scrape African - Ewe for Female names...
# Fetching data for African - Ewe (Female) with seed 0...
# Fetching data for African - Ewe (Female) with seed 50...
# No more data found for African - Ewe (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Ewe (Female).
# Total records collected so far: 714
#
# Starting to scrape African - Fanti for Female names...
# Fetching data for African - Fanti (Female) with seed 0...
# No more data found for African - Fanti (Female) at seed 0. Stopping seed increment.
# No data found for African - Fanti (Female).
# Total records collected so far: 714
#
# Starting to scrape African - Ghanian for Female names...
# Fetching data for African - Ghanian (Female) with seed 0...
# Fetching data for African - Ghanian (Female) with seed 50...
# No more data found for African - Ghanian (Female) at seed 50. Stopping seed increment.
# Successfully scraped 34 records for African - Ghanian (Female).
# Total records collected so far: 748
#
# Starting to scrape African - Hausa for Female names...
# Fetching data for African - Hausa (Female) with seed 0...
# Fetching data for African - Hausa (Female) with seed 50...
# No more data found for African - Hausa (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Hausa (Female).
# Total records collected so far: 749
#
# Starting to scrape African - Ibo for Female names...
# Fetching data for African - Ibo (Female) with seed 0...
# Fetching data for African - Ibo (Female) with seed 50...
# No more data found for African - Ibo (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Ibo (Female).
# Total records collected so far: 750
#
# Starting to scrape African - Kenyan for Female names...
# Fetching data for African - Kenyan (Female) with seed 0...
# Fetching data for African - Kenyan (Female) with seed 50...
# No more data found for African - Kenyan (Female) at seed 50. Stopping seed increment.
# Successfully scraped 3 records for African - Kenyan (Female).
# Total records collected so far: 753
#
# Starting to scrape African - Kikuyu for Female names...
# Fetching data for African - Kikuyu (Female) with seed 0...
# No more data found for African - Kikuyu (Female) at seed 0. Stopping seed increment.
# No data found for African - Kikuyu (Female).
# Total records collected so far: 753
#
# Starting to scrape African - Lesotho for Female names...
# Fetching data for African - Lesotho (Female) with seed 0...
# No more data found for African - Lesotho (Female) at seed 0. Stopping seed increment.
# No data found for African - Lesotho (Female).
# Total records collected so far: 753
#
# Starting to scrape African - Lugandan for Female names...
# Fetching data for African - Lugandan (Female) with seed 0...
# Fetching data for African - Lugandan (Female) with seed 50...
# No more data found for African - Lugandan (Female) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Lugandan (Female).
# Total records collected so far: 755
#
# Starting to scrape African - Malawian for Female names...
# Fetching data for African - Malawian (Female) with seed 0...
# Fetching data for African - Malawian (Female) with seed 50...
# No more data found for African - Malawian (Female) at seed 50. Stopping seed increment.
# Successfully scraped 9 records for African - Malawian (Female).
# Total records collected so far: 764
#
# Starting to scrape African - Musoga for Female names...
# Fetching data for African - Musoga (Female) with seed 0...
# Fetching data for African - Musoga (Female) with seed 50...
# No more data found for African - Musoga (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Musoga (Female).
# Total records collected so far: 765
#
# Starting to scrape African - Nguni for Female names...
# Fetching data for African - Nguni (Female) with seed 0...
# No more data found for African - Nguni (Female) at seed 0. Stopping seed increment.
# No data found for African - Nguni (Female).
# Total records collected so far: 765
#
# Starting to scrape African - Nigerian for Female names...
# Fetching data for African - Nigerian (Female) with seed 0...
# Fetching data for African - Nigerian (Female) with seed 50...
# Fetching data for African - Nigerian (Female) with seed 100...
# Fetching data for African - Nigerian (Female) with seed 150...
# No more data found for African - Nigerian (Female) at seed 150. Stopping seed increment.
# Successfully scraped 103 records for African - Nigerian (Female).
# Total records collected so far: 868
#
# Starting to scrape African - Ochi for Female names...
# Fetching data for African - Ochi (Female) with seed 0...
# No more data found for African - Ochi (Female) at seed 0. Stopping seed increment.
# No data found for African - Ochi (Female).
# Total records collected so far: 868
#
# Starting to scrape African - Rukonjo for Female names...
# Fetching data for African - Rukonjo (Female) with seed 0...
# No more data found for African - Rukonjo (Female) at seed 0. Stopping seed increment.
# No data found for African - Rukonjo (Female).
# Total records collected so far: 868
#
# Starting to scrape African - Runyoro for Female names...
# Fetching data for African - Runyoro (Female) with seed 0...
# No more data found for African - Runyoro (Female) at seed 0. Stopping seed increment.
# No data found for African - Runyoro (Female).
# Total records collected so far: 868
#
# Starting to scrape African - Rutooro for Female names...
# Fetching data for African - Rutooro (Female) with seed 0...
# No more data found for African - Rutooro (Female) at seed 0. Stopping seed increment.
# No data found for African - Rutooro (Female).
# Total records collected so far: 868
#
# Starting to scrape African - Rwandan for Female names...
# Fetching data for African - Rwandan (Female) with seed 0...
# Fetching data for African - Rwandan (Female) with seed 50...
# No more data found for African - Rwandan (Female) at seed 50. Stopping seed increment.
# Successfully scraped 3 records for African - Rwandan (Female).
# Total records collected so far: 871
#
# Starting to scrape African - Somalian for Female names...
# Fetching data for African - Somalian (Female) with seed 0...
# Fetching data for African - Somalian (Female) with seed 50...
# No more data found for African - Somalian (Female) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Somalian (Female).
# Total records collected so far: 873
#
# Starting to scrape African - Swahili for Female names...
# Fetching data for African - Swahili (Female) with seed 0...
# Fetching data for African - Swahili (Female) with seed 50...
# Fetching data for African - Swahili (Female) with seed 100...
# No more data found for African - Swahili (Female) at seed 100. Stopping seed increment.
# Successfully scraped 76 records for African - Swahili (Female).
# Total records collected so far: 949
#
# Starting to scrape African - Tanzanian for Female names...
# Fetching data for African - Tanzanian (Female) with seed 0...
# Fetching data for African - Tanzanian (Female) with seed 50...
# No more data found for African - Tanzanian (Female) at seed 50. Stopping seed increment.
# Successfully scraped 10 records for African - Tanzanian (Female).
# Total records collected so far: 959
#
# Starting to scrape African - Ugandan for Female names...
# Fetching data for African - Ugandan (Female) with seed 0...
# Fetching data for African - Ugandan (Female) with seed 50...
# No more data found for African - Ugandan (Female) at seed 50. Stopping seed increment.
# Successfully scraped 4 records for African - Ugandan (Female).
# Total records collected so far: 963
#
# Starting to scrape African - Xhosha for Female names...
# Fetching data for African - Xhosha (Female) with seed 0...
# Fetching data for African - Xhosha (Female) with seed 50...
# No more data found for African - Xhosha (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Xhosha (Female).
# Total records collected so far: 964
#
# Starting to scrape African - Yoruba for Female names...
# Fetching data for African - Yoruba (Female) with seed 0...
# No more data found for African - Yoruba (Female) at seed 0. Stopping seed increment.
# No data found for African - Yoruba (Female).
# Total records collected so far: 964
#
# Starting to scrape African - Yoruban for Female names...
# Fetching data for African - Yoruban (Female) with seed 0...
# No more data found for African - Yoruban (Female) at seed 0. Stopping seed increment.
# No data found for African - Yoruban (Female).
# Total records collected so far: 964
#
# Starting to scrape African - Zimbabwe for Female names...
# Fetching data for African - Zimbabwe (Female) with seed 0...
# Fetching data for African - Zimbabwe (Female) with seed 50...
# No more data found for African - Zimbabwe (Female) at seed 50. Stopping seed increment.
# Successfully scraped 13 records for African - Zimbabwe (Female).
# Total records collected so far: 977
#
# Starting to scrape African - Zulu for Female names...
# Fetching data for African - Zulu (Female) with seed 0...
# Fetching data for African - Zulu (Female) with seed 50...
# No more data found for African - Zulu (Female) at seed 50. Stopping seed increment.
# Successfully scraped 2 records for African - Zulu (Female).
# Total records collected so far: 979
#
# Starting to scrape African - Zuni for Female names...
# Fetching data for African - Zuni (Female) with seed 0...
# Fetching data for African - Zuni (Female) with seed 50...
# No more data found for African - Zuni (Female) at seed 50. Stopping seed increment.
# Successfully scraped 1 records for African - Zuni (Female).
# Total records collected so far: 980
#
# Starting to scrape Arabic for Female names...
# Fetching data for Arabic (Female) with seed 0...
# Fetching data for Arabic (Female) with seed 50...
# Fetching data for Arabic (Female) with seed 100...
# Fetching data for Arabic (Female) with seed 150...
# Fetching data for Arabic (Female) with seed 200...
# Fetching data for Arabic (Female) with seed 250...
# Fetching data for Arabic (Female) with seed 300...
# Fetching data for Arabic (Female) with seed 350...
# No more data found for Arabic (Female) at seed 350. Stopping seed increment.
# Successfully scraped 309 records for Arabic (Female).
# Total records collected so far: 1289
# Data has been scraped and saved to 'african_names.csv'

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# To ensure that our dataset for the Baby Name Generator is both accurate and user-friendly, we undertook several key preprocessing steps:
#
# Removing Unnecessary Columns: We streamlined the dataset by eliminating columns that were not essential for the naming process. This helped to focus on the most relevant information and improve the efficiency of data handling.
#
# Adding New Columns:
#
# - **Name Length**: We calculated the length of each name to provide an additional parameter for users who may prefer names of specific lengths.
#
# - **First Letter**: We extracted the first letter of each name, allowing users to filter names based on their starting letter.
#
# - **Transforming Name Format**: To maintain consistency and enhance readability, we transformed all names into InitCap format.
#
# This formatting capitalizes the first letter of each name while keeping the remaining letters in lowercase, making the names visually appealing and standard across the dataset.
#
# These preprocessing steps were crucial for refining the dataset and ensuring that the Baby Name Generator delivers accurate, well-organized, and easily accessible name suggestions.

# %%
# Load the existing CSV file
df = pd.read_csv('african_names.csv')
df.to_csv('african_names.csv', index=False)

# %%
import pandas as pd

# Load the existing CSV file
df = pd.read_csv('african_names.csv')

# Drop the 'Sex' and 'Variations' columns
df = df.drop(columns=['Sex', 'Variations'])

# Save the modified DataFrame back to the original CSV file
df.to_csv('african_names.csv', index=False)
print("Removed 'Sex' and 'Variations' columns from african_names.csv.")
# Out:
# Removed 'Sex' and 'Variations' columns from african_names.csv.

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                  Category  Gender     Name               Origin  \
# 0     African - Abaluhyan    Male   Jimiyu  African---Abaluhyan
# 1          African - Akan    Male   Donkor       African---Akan
# 2          African - Akan    Male   Minkah       African---Akan
# 3      African - American    Male   Chikae   African---American
# 4      African - American    Male  Cleavon   African---American
# ...                   ...     ...      ...                  ...
# 1284               Arabic  Female   Zarifa               Arabic
# 1285               Arabic  Female   Zaynab               Arabic
# 1286               Arabic  Female  Zubaida               Arabic
# 1287               Arabic  Female  Zuleika               Arabic
# 1288               Arabic  Female   Zurafa               Arabic
#
#                          Meaning
# 0     Born during the dry season
# 1                         Humble
# 2                   Light haired
# 3                   Power of God
# 4                          Cliff
# ...                          ...
# 1284                    Graceful
# 1285                       Plant
# 1286             Marigold flower
# 1287           Brilliant, lovely
# 1288           Lovely, beautiful
#
# [1289 rows x 5 columns]>

# %% [markdown]
# names are in InitCap format, added 2 new columns for name length and name first letter

# %%
# Ensure that all names are in InitCap format (e.g., 'John' instead of 'john' or 'JOHN')
df['Name'] = df['Name'].str.title()

# Add a new column for the length of each name
df['Name Length'] = df['Name'].apply(len)

# Add a new column for the first letter of each name
df['First Letter'] = df['Name'].str[0]

# Save the modified DataFrame back to the original CSV file
df.to_csv('african_names.csv', index=False)

print("All names have been converted to InitCap format, and new columns 'Name Length' and 'First Letter' have been added.")
# Out:
# All names have been converted to InitCap format, and new columns 'Name Length' and 'First Letter' have been added.

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                  Category  Gender     Name               Origin  \
# 0     African - Abaluhyan    Male   Jimiyu  African---Abaluhyan
# 1          African - Akan    Male   Donkor       African---Akan
# 2          African - Akan    Male   Minkah       African---Akan
# 3      African - American    Male   Chikae   African---American
# 4      African - American    Male  Cleavon   African---American
# ...                   ...     ...      ...                  ...
# 1284               Arabic  Female   Zarifa               Arabic
# 1285               Arabic  Female   Zaynab               Arabic
# 1286               Arabic  Female  Zubaida               Arabic
# 1287               Arabic  Female  Zuleika               Arabic
# 1288               Arabic  Female   Zurafa               Arabic
#
#                          Meaning  Name Length First Letter
# 0     Born during the dry season            6            J
# 1                         Humble            6            D
# 2                   Light haired            6            M
# 3                   Power of God            6            C
# 4                          Cliff            7            C
# ...                          ...          ...          ...
# 1284                    Graceful            6            Z
# 1285                       Plant            6            Z
# 1286             Marigold flower            7            Z
# 1287           Brilliant, lovely            7            Z
# 1288           Lovely, beautiful            6            Z
#
# [1289 rows x 7 columns]>

# %% [markdown]
# # **Relevant word extraction**

# %% [markdown]
# To enhance the Baby Name Generator’s ability to filter names based on their meanings, we applied a sophisticated approach to categorize these meanings into distinct groups. Here’s an overview of the process:
#
# **Clustering Meanings**: We utilized a zero-shot classification model to categorize the meanings of names into predefined categories. This approach allows for flexible and dynamic classification without the need for a labeled training dataset specific to our categories.
#
# **Model Used**: facebook/bart-large-mnli from the Hugging Face Transformers library. This model is known for its ability to perform zero-shot classification, which is particularly useful for assigning meanings to categories without explicit training on those categories.
#
# **User Input Integration**: This categorization will be integrated into the Baby Name Generator, allowing users to input their desired categories or themes. The generator will then filter and suggest names that match those categories based on the meanings.
#
# By leveraging zero-shot classification for meaning-based clustering, we have significantly enhanced the functionality of the Baby Name Generator, providing users with a powerful tool to find names that resonate with their personal and cultural preferences.

# %%
import pandas as pd
from transformers import pipeline

# Ensure there are no NaN or empty strings in the 'Meaning' column
df = df[df['Meaning'].notna() & (df['Meaning'].str.strip() != '')]

# Define candidate labels for classification
candidate_labels = ['Nature', 'God', 'Intellectual Qualities', 'Virtues', 'Strength and Power', 
                    'Leadership and Royalty', 'Social Roles', 'Family relations', 'Birth Order', 
                    'Emotions', 'Objects', 'Time','Love']

# Initialize the zero-shot classifier
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")

# Function to classify each relevant word (sentence in this case)
def classify_sentence(sentence, threshold=0.5):
    if isinstance(sentence, str) and sentence.strip():  # Ensure sentence is a non-empty string
        result = classifier(sentence, candidate_labels)
        # Get the label with the highest score and its score
        top_label = result['labels'][0]
        top_score = result['scores'][0]
        # Check if the top score meets the threshold
        if top_score >= threshold:
            return top_label
        else:
            return 'nothing'
    return 'nothing'  # Return 'nothing' if classification fails

# Apply the classification function to the 'Meaning' column
df['Category'] = df['Meaning'].apply(lambda x: classify_sentence(x))

# Display the updated DataFrame
print(df.head(20))
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
#        Category Gender      Name               Origin  \
# 0       nothing   Male    Jimiyu  African---Abaluhyan
# 1       nothing   Male    Donkor       African---Akan
# 2       nothing   Male    Minkah       African---Akan
# 3       nothing   Male    Chikae   African---American
# 4       nothing   Male   Cleavon   African---American
# 5       nothing   Male      Elon   African---American
# 6       nothing   Male      Kivi   African---American
# 7       Virtues   Male  Laphonso   African---American
# 8       nothing   Male     Masio   African---American
# 9   Birth Order   Male  Quadrees   African---American
# 10      nothing   Male    Baruti   African---Botswana
# 11      nothing   Male   Fenyang   African---Botswana
# 12      nothing   Male  Kefentse   African---Botswana
# 13      nothing   Male    Kopano   African---Botswana
# 14      nothing   Male   Montsho   African---Botswana
# 15      nothing   Male      Tale   African---Botswana
# 16      nothing   Male       Tau   African---Botswana
# 17      nothing   Male     Ammon   African---Egyptian
# 18       Nature   Male       Geb   African---Egyptian
# 19          God   Male     Horus   African---Egyptian
#
#                        Meaning  Name Length First Letter
# 0   Born during the dry season            6            J
# 1                       Humble            6            D
# 2                 Light haired            6            M
# 3                 Power of God            6            C
# 4                        Cliff            7            C
# 5                       Spirit            4            E
# 6     One who lives by a stone            4            K
# 7                        Noble            8            L
# 8                         Twin            5            M
# 9            Fourth born child            8            Q
# 10                     Teacher            6            B
# 11                   Conqueror            7            F
# 12                   Conqueror            8            K
# 13                       Union            6            K
# 14                 Black, dark            7            M
# 15                       Green            4            T
# 16                        Lion            3            T
# 17              Hidden, secret            5            A
# 18                       Earth            3            G
# 19              God of the sky            5            H

# %%
print(df)
# Out:
#      Category  Gender     Name               Origin  \
# 0     nothing    Male   Jimiyu  African---Abaluhyan
# 1     nothing    Male   Donkor       African---Akan
# 2     nothing    Male   Minkah       African---Akan
# 3     nothing    Male   Chikae   African---American
# 4     nothing    Male  Cleavon   African---American
# ...       ...     ...      ...                  ...
# 1284  nothing  Female   Zarifa               Arabic
# 1285   Nature  Female   Zaynab               Arabic
# 1286   Nature  Female  Zubaida               Arabic
# 1287  nothing  Female  Zuleika               Arabic
# 1288  nothing  Female   Zurafa               Arabic
#
#                          Meaning  Name Length First Letter
# 0     Born during the dry season            6            J
# 1                         Humble            6            D
# 2                   Light haired            6            M
# 3                   Power of God            6            C
# 4                          Cliff            7            C
# ...                          ...          ...          ...
# 1284                    Graceful            6            Z
# 1285                       Plant            6            Z
# 1286             Marigold flower            7            Z
# 1287           Brilliant, lovely            7            Z
# 1288           Lovely, beautiful            6            Z
#
# [1289 rows x 7 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame
# Save the DataFrame as a CSV file to the Kaggle working directory
df.to_csv('/kaggle/working/names.csv', index=False)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In summary, the Baby Name Generator has been designed to offer a personalized and intuitive naming experience for parents. Based on our comprehensive work, the generator now provides the following capabilities:
#
# User-Defined Criteria:
#
# **Gender**: Users can specify whether they are looking for names for boys, girls, or any gender.
#
# **Origin**: Users can select names based on their geographical origins.
#
# **Name Length**: Users can filter names by their length, choosing from short, medium, or long names.
#
# **First Letter**: Users can specify the starting letter of the names they are interested in.
#
# **Meaning**: Users can enter keywords related to the meanings they want, and the generator will use advanced classification to filter names accordingly.
#
#
# Enhanced User Experience:
#
# With these features, the Baby Name Generator empowers parents to make informed and meaningful choices for their child’s name. It combines cultural richness with modern technology, providing a streamlined and enjoyable naming process.
#
# Overall, the Baby Name Generator is a valuable tool for anyone seeking a name that perfectly fits their preferences and values, making the name selection process both easier and more meaningful.
